# %% [markdown]
# # Build the shared feature table
#
# One row per game with as-of features (known before kickoff) plus every period target. Every model notebook reads this table.

# %%
import numpy as np
import pandas as pd

from canes_cfb.markets import MARKETS, PERIOD_COMPONENTS, MarketType, Period
from canes_cfb.paths import PREDICTIONS, PROCESSED

pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## 1. Targets per period

# %% [markdown]
# ## 2. Team ratings and efficiency features

# %% [markdown]
# ## 3. Save to data/processed
